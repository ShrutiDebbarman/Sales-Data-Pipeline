# %%
import pandas as pd
df = pd.read_excel("C:/Users/SHRUTI/Downloads/sales_data_pipeline_dataset_20k_added.xlsx")
print(df.head())
# Out:
#    order_id  order_date customer_name       state  product  quantity  price
# 0      1001  2024-06-10         Karan  Tamil Nadu   Laptop         2  60000
# 1      1002  2024-06-29          Neha  Tamil Nadu   Laptop         3  60000
# 2      1003  2024-03-11          Neha       Delhi    Mouse         5    500
# 3      1004  2024-05-02         Arjun      Kerala  Monitor         3  12000
# 4      1005  2024-06-10         Anita      Kerala    Mouse         1    500

# %%
import pandas as pd

def transform_data(df):

    df = df.drop_duplicates()

    df['order_date'] = pd.to_datetime(df['order_date'])

    df['total_sales'] = df['quantity'] * df['price']

    return df
print(df)
# Out:
#        order_id  order_date customer_name        state   product  quantity  \
# 0          1001  2024-06-10         Karan   Tamil Nadu    Laptop         2
# 1          1002  2024-06-29          Neha   Tamil Nadu    Laptop         3
# 2          1003  2024-03-11          Neha        Delhi     Mouse         5
# 3          1004  2024-05-02         Arjun       Kerala   Monitor         3
# 4          1005  2024-06-10         Anita       Kerala     Mouse         1
# ...         ...         ...           ...          ...       ...       ...
# 20995      1232  2024-06-06         Anita   Tamil Nadu    Tablet         2
# 20996      1145  2024-05-13         Karan       Kerala     Mouse         3
# 20997      1762  2024-05-12         Rahul  Maharashtra  Keyboard         2
# 20998      1047  2024-04-09          Neha    Telangana     Phone         5
# 20999      1063  2024-04-26         Arjun    Karnataka  Keyboard         4
#
#        price
# 0      60000
# 1      60000
# 2        500
# ...

# %%
from sqlalchemy import create_engine
import pandas as pd

engine = create_engine(
"postgresql://postgres:240701@localhost:5432/sales_db"
)

df = pd.read_excel("C:/Users/SHRUTI/Downloads/sales_data_pipeline_dataset_20k_added.xlsx")

df['order_date'] = pd.to_datetime(df['order_date'])
df['total_sales'] = df['quantity'] * df['price']

df.to_sql(
    "sales_fact",
    engine,
    if_exists="append",
    index=False
)
# Out:
# 1000

# %%
import pandas as pd
from sqlalchemy import create_engine

# Extract
df = pd.read_excel("C:/Users/SHRUTI/Downloads/sales_data_pipeline_dataset_20k_added.xlsx")

# Transform
df = df.drop_duplicates()
df['order_date'] = pd.to_datetime(df['order_date'])
df['total_sales'] = df['quantity'] * df['price']

# Load
engine = create_engine(
"postgresql://postgres:240701@localhost:5432/sales_db"
)

df.to_sql("sales_fact", engine, if_exists="append", index=False)

print("ETL Completed")
# Out:
# ETL Completed
